# %% [markdown]
# <a href="https://colab.research.google.com/github/ai-aarthi/collab/blob/python/day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# DATA TYPES , OPERATORS, DATA STRUCTURES/COLLECTION

# %%
w = 12
x = 4.6
s = True
p = False
c = 5+6j
"AARTHI","tANVI","2112232323",'rose'

# %%
a = 12

# %%
a+10
# Out:
# 22

# %%
b = 10

# %%
b != 100
# Out:
# True

# %% [markdown]
# 1. create - encloser , function
# 2. empty version possible
# 3. allow all datatype
# 4. duplication
# 5. countable
# 6. indexable
# 7. ordered/unordered
# 8. nesting

# %%
l = []
l1 = list()

# %%
type (l)
type (l1)
# Out:
# list
